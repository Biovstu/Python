# %%
'''
f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30

1. Определить корни
2. Найти интервалы, на которых функция возрастает
3. Найти интервалы, на которых функция убывает
4. Построить график
5. Вычислить вершину
6. Определить промежутки, на котором f > 0
7. Определить промежутки, на котором f < 0
'''

# %%
import sympy
import matplotlib

# %%
x = sympy.Symbol('x')

# %%
f_x = -12 * x ** 4 * sympy.sin(sympy.cos(x)) - 18 * x ** 3 + 5 * x ** 2 + 10 * x - 30
print(f_x)
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
for i in range(393000, 393100):
    print(f'{i} = {f_x.subs(x, i/10000).evalf()}')
# Out:
# 393000 = -223356.263906564
# 393001 = -220495.830335911
# 393002 = -217635.355792294
# 393003 = -214774.840332260
# 393004 = -211914.284012972
# 393005 = -209053.686891591
# 393006 = -206193.049024669
# 393007 = -203332.370469576
# 393008 = -200471.651282867
# 393009 = -197610.891521911
# 393010 = -194750.091243268
# 393011 = -191889.250504310
# 393012 = -189028.369361599
# 393013 = -186167.447872509
# 393014 = -183306.486093604
# 393015 = -180445.484082263
# 393016 = -177584.441895050
# 393017 = -174723.359589346
# 393018 = -171862.237221720
# 393019 = -169001.074849352
# 393020 = -166139.872529421
# 393021 = -163278.630318501
# 393022 = -160417.348273976
# 393023 = -157556.026452424
# 393024 = -154694.664911232
# 393025 = -151833.263706977
# 393026 = -148971.822897050
# 393027 = -146110.342538032
# 393028 = -143248.822687316
# 393029 = -140387.263401483
# 393030 = -137525.664737931
# 393031 = -134664.026753243
# 393032 = -131802.349504818
# 393033 = -128940.633049242
# ...

# %% [markdown]
# Один из корней между
# 39,3078 = -123.737732370850
# 39,3079 = 2739.72061304608

# %%
sympy.solve(-12 * x ** 4 * sympy.sin(sympy.cos(x)), x)
# Out:
# [0, pi/2, 3*pi/2, 2*pi - acos(pi), acos(pi)]

# %%
sympy.solve(-18 * x ** 3 + 5 * x ** 2 + 10 * x - 30, x)
# Out:
# [5/54 - 565/(972*(-1/2 - sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3,
#  5/54 - (-1/2 + sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3 - 565/(972*(-1/2 + sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)),
#  -(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3 - 565/(972*(5*sqrt(218931)/108 + 127045/5832)**(1/3)) + 5/54]

# %%
sympy.plotting.plot(f_x, (x, 38, 42))

# %%
diff_f_x = f_x.diff(x)
print(diff_f_x)
# Out:
# 12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10

# %%
sympy.plotting.plot(diff_f_x, (x, 40.95, 40.99))

# %%
diff_f_x.subs(x, 40.98493).evalf()
# Out:
# -16.7849443880841

# %%
f.subs(x, 4).evalf()
# Out:
# 16.0000000000000
